# %%
#importing necessary packages
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import mpl_toolkits
# %matplotlib inline

# %%
#importing data set
HAR = pd.read_csv("HAR_Dataset.csv")

# %%
#checking the head of data set
HAR.head()
# Out:
#          V1        V2        V3        V4        V5        V6        V7  \
# 0  0.288585 -0.020294 -0.132905 -0.995279 -0.983111 -0.913526 -0.995112
# 1  0.278419 -0.016411 -0.123520 -0.998245 -0.975300 -0.960322 -0.998807
# 2  0.279653 -0.019467 -0.113462 -0.995380 -0.967187 -0.978944 -0.996520
# 3  0.279174 -0.026201 -0.123283 -0.996091 -0.983403 -0.990675 -0.997099
# 4  0.276629 -0.016570 -0.115362 -0.998139 -0.980817 -0.990482 -0.998321
#
#          V8        V9       V10  ...        V553      V554      V555  \
# 0 -0.983185 -0.923527 -0.934724  ...   -0.298676 -0.710304 -0.112754
# 1 -0.974914 -0.957686 -0.943068  ...   -0.595051 -0.861499  0.053477
# 2 -0.963668 -0.977469 -0.938692  ...   -0.390748 -0.760104 -0.118559
# 3 -0.982750 -0.989303 -0.938692  ...   -0.117290 -0.482845 -0.036788
# 4 -0.979672 -0.990441 -0.942469  ...   -0.351471 -0.699205  0.123320
#
#        V556      V557      V558      V559      V560      V561  Class
# ...

# %%
#checking the shape of data set
HAR.shape
# Out:
# (10299, 562)

# %%
#checking frequency of classes
HAR['Class'].value_counts()
# Out:
# 6    1944
# 5    1906
# 4    1777
# 1    1722
# 2    1544
# 3    1406
# Name: Class, dtype: int64

# %%
#countplot of classes
sns.countplot(x='Class', data= HAR, palette='hls')
plt.show()
plt.savefig('count_plot')

# %%
y = HAR['Class']

# %%
y.shape
# Out:
# (10299,)

# %%
type(y)
# Out:
# pandas.core.series.Series

# %%
y.shape
# Out:
# (10299,)

# %%
y
# Out:
# 0        5
# 1        5
# 2        5
# 3        5
# 4        5
# 5        5
# 6        5
# 7        5
# 8        5
# 9        5
# 10       5
# 11       5
# 12       5
# 13       5
# 14       5
# 15       5
# 16       5
# 17       5
# 18       5
# 19       5
# 20       5
# 21       5
# 22       5
# 23       5
# 24       5
# 25       5
# 26       5
# 27       4
# 28       4
# 29       4
#         ..
# 10269    2
# 10270    2
# 10271    2
# 10272    2
# 10273    2
# 10274    2
# 10275    2
# 10276    2
# 10277    2
# 10278    2
# 10279    2
# 10280    3
# 10281    3
# 10282    3
# 10283    3
# 10284    3
# 10285    3
# 10286    3
# 10287    3
# 10288    3
# 10289    2
# 10290    2
# 10291    2
# 10292    2
# 10293    2
# 10294    2
# 10295    2
# 10296    2
# 10297    2
# 10298    2
# Name: Class, Length: 10299, dtype: int64

# %%
HAR.drop('Class',axis=1,inplace=True)

# %%
HAR.shape
# Out:
# (10299, 561)

# %%
X = HAR

# %%
X.shape
# Out:
# (10299, 561)

# %%
type(X)
# Out:
# pandas.core.frame.DataFrame

# %%
X
# Out:
#              V1        V2        V3        V4        V5        V6        V7  \
# 0      0.288585 -0.020294 -0.132905 -0.995279 -0.983111 -0.913526 -0.995112
# 1      0.278419 -0.016411 -0.123520 -0.998245 -0.975300 -0.960322 -0.998807
# 2      0.279653 -0.019467 -0.113462 -0.995380 -0.967187 -0.978944 -0.996520
# 3      0.279174 -0.026201 -0.123283 -0.996091 -0.983403 -0.990675 -0.997099
# 4      0.276629 -0.016570 -0.115362 -0.998139 -0.980817 -0.990482 -0.998321
# 5      0.277199 -0.010098 -0.105137 -0.997335 -0.990487 -0.995420 -0.997627
# 6      0.279454 -0.019641 -0.110022 -0.996921 -0.967186 -0.983118 -0.997003
# 7      0.277432 -0.030488 -0.125360 -0.996559 -0.966728 -0.981585 -0.996485
# 8      0.277293 -0.021751 -0.120751 -0.997328 -0.961245 -0.983672 -0.997596
# 9      0.280586 -0.009960 -0.106065 -0.994803 -0.972758 -0.986244 -0.995405
# 10     0.276880 -0.012722 -0.103438 -0.994815 -0.973077 -0.985357 -0.995509
# ...

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=42)

# %%
X_train.shape
# Out:
# (7209, 561)

# %%
X_test.shape
# Out:
# (3090, 561)

# %%
y_train.shape
# Out:
# (7209,)

# %%
y_test.shape
# Out:
# (3090,)

# %% [markdown]
# Exploratory Data Analysis

# %% [markdown]
# Checking for missing values
#
# The very first exploratry analysis that we want to see if our training data has some missing values. we have generated a heat map where we would get to know by color marks that which feature has missing values in them.
# It looks like the data set has no missing values and we are good to go with furthur analysis.

# %%
sns.heatmap(X_train.isnull(),yticklabels=False,cbar=False,cmap='viridis')

# %% [markdown]
# 3D visualization of features.
#
# We created our 3d plot between the first hree features which are. since we will be using classifiers like KNN,  SVM in our training models, it is highly recommended to normalize the data in a specific range as these classifiers are dependent on distance and units between different features can vary.
# From the following visualization you can see that the data is in the range of -1 to 1.

# %%
from mpl_toolkits.mplot3d import Axes3D

# %%
first_variable=X_train['V1']

# %%
second_variable=X_train['V2']

# %%
third_variable=X_train['V3']

# %%
fig = plt.figure(figsize=(20,8))
ax = Axes3D(fig)
ax.scatter3D(first_variable,second_variable,third_variable)
